# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as snsperplexité
import os
import sys
from sklearn.manifold import TSNE

# %%
files = [file for file in os.listdir() if file.endswith(".csv") ]
files
# Out:
# ['newthyroid.csv',
#  'pasture.csv',
#  'squash-stored.csv',
#  'bondrate.csv',
#  'car.csv',
#  'contact-lenses.csv']

# %%
def plot_tsne(file, perplexity = 25):
  data = pd.read_csv(file, header=None, sep=" ")
  n_col = len(data.columns)

  tsne = TSNE(perplexity=perplexity)
  data_transformed = tsne.fit_transform(data[list(range(n_col))])

  plt.scatter(data_transformed[:, 0], data_transformed[:, 1], c=data.iloc[:, -1])
  plt.title(file)
  plt.show()

# %%
#perplexité=5
for file in files:
  print(file)
  plot_tsne(file)
# Out:
# newthyroid.csv
# /usr/lib64/python3.11/site-packages/sklearn/manifold/_t_sne.py:800: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /usr/lib64/python3.11/site-packages/sklearn/manifold/_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# pasture.csv
# /usr/lib64/python3.11/site-packages/sklearn/manifold/_t_sne.py:800: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /usr/lib64/python3.11/site-packages/sklearn/manifold/_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# squash-stored.csv
# /usr/lib64/python3.11/site-packages/sklearn/manifold/_t_sne.py:800: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# ...

# %%
#perplexité=10
for file in files:
  print(file)
  plot_tsne(file)
# Out:
# newthyroid.csv
# /usr/lib64/python3.11/site-packages/sklearn/manifold/_t_sne.py:800: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /usr/lib64/python3.11/site-packages/sklearn/manifold/_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# pasture.csv
# /usr/lib64/python3.11/site-packages/sklearn/manifold/_t_sne.py:800: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /usr/lib64/python3.11/site-packages/sklearn/manifold/_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# squash-stored.csv
# /usr/lib64/python3.11/site-packages/sklearn/manifold/_t_sne.py:800: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# ...

# %%
#perplexité=25
for file in files:
  print(file)
  plot_tsne(file)
# Out:
# newthyroid.csv
# /usr/lib64/python3.11/site-packages/sklearn/manifold/_t_sne.py:800: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /usr/lib64/python3.11/site-packages/sklearn/manifold/_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# pasture.csv
# /usr/lib64/python3.11/site-packages/sklearn/manifold/_t_sne.py:800: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /usr/lib64/python3.11/site-packages/sklearn/manifold/_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# squash-stored.csv
# /usr/lib64/python3.11/site-packages/sklearn/manifold/_t_sne.py:800: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# ...

# %%
lenses=pd.read_csv(files[-1])
len(lenses) #Perplexité ne peut dépasser le nombre d'individus de l'échantillon
# Out:
# 23
